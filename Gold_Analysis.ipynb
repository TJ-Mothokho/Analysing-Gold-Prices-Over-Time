# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Question 2
# Getting the data from the gold.csv file

# %%
gold = pd.read_csv(r'gold.csv')
gold.head()
# Out:
#       Date  Price
# 0  1950-01  34.73
# 1  1950-02  34.73
# 2  1950-03  34.73
# 3  1950-04  34.73
# 4  1950-05  34.73

# %% [markdown]
# # Question 3
# running the info() method

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    847 non-null    object
#  1   Price   847 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.4+ KB

# %% [markdown]
# # Question 4
# Converting Date column to DateTime Data Type

# %%
gold['Date'] = gold['Date'].apply(pd.to_datetime)
gold.head()
# Out:
#         Date  Price
# 0 1950-01-01  34.73
# 1 1950-02-01  34.73
# 2 1950-03-01  34.73
# 3 1950-04-01  34.73
# 4 1950-05-01  34.73

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    847 non-null    datetime64[ns]
#  1   Price   847 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 13.4 KB

# %% [markdown]
# # Question 5
# Plotting data with Pandas Line Plot

# %%
gold.plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Question 6
# Generate time period

# %%
#setting date as index
gold.set_index('Date', inplace=True)
gold.head()
# Out:
#             Price
# Date
# 1950-01-01  34.73
# 1950-02-01  34.73
# 1950-03-01  34.73
# 1950-04-01  34.73
# 1950-05-01  34.73

# %%
firstDay_of_eachYear = pd.date_range(start='1950/01/01', end='2020/12/31', freq='YS')
firstDay_of_eachYear
# Out:
# DatetimeIndex(['1950-01-01', '1951-01-01', '1952-01-01', '1953-01-01',
#                '1954-01-01', '1955-01-01', '1956-01-01', '1957-01-01',
#                '1958-01-01', '1959-01-01', '1960-01-01', '1961-01-01',
#                '1962-01-01', '1963-01-01', '1964-01-01', '1965-01-01',
#                '1966-01-01', '1967-01-01', '1968-01-01', '1969-01-01',
#                '1970-01-01', '1971-01-01', '1972-01-01', '1973-01-01',
#                '1974-01-01', '1975-01-01', '1976-01-01', '1977-01-01',
#                '1978-01-01', '1979-01-01', '1980-01-01', '1981-01-01',
#                '1982-01-01', '1983-01-01', '1984-01-01', '1985-01-01',
#                '1986-01-01', '1987-01-01', '1988-01-01', '1989-01-01',
#                '1990-01-01', '1991-01-01', '1992-01-01', '1993-01-01',
#                '1994-01-01', '1995-01-01', '1996-01-01', '1997-01-01',
#                '1998-01-01', '1999-01-01', '2000-01-01', '2001-01-01',
#                '2002-01-01', '2003-01-01', '2004-01-01', '2005-01-01',
#                '2006-01-01', '2007-01-01', '2008-01-01', '2009-01-01',
#                '2010-01-01', '2011-01-01', '2012-01-01', '2013-01-01',
#                '2014-01-01', '2015-01-01', '2016-01-01', '2017-01-01',
#                '2018-01-01', '2019-01-01', '2020-01-01'],
#               dtype='datetime64[ns]', freq='AS-JAN')

# %% [markdown]
# # Question 7
# reindex the data

# %%
gold = gold.reindex(firstDay_of_eachYear)
gold.head()
# Out:
#             Price
# 1950-01-01  34.73
# 1951-01-01  34.72
# 1952-01-01  34.49
# 1953-01-01  34.88
# 1954-01-01  34.86

# %% [markdown]
# # Question 8
# Plot the reindexed data in pandas line plot

# %%
gold.plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Question 9
# Resample data (upsample)

# %%
gold = gold.resample(rule='Q').sum()
gold.plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Question 10
# Resample the data (downsample)

# %%
gold = gold.resample(rule='Y').sum()
gold.plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Question 11
# Plot the rolling mean in a pandas line plot

# %%
gold.rolling(window=2).mean().plot()
# Out:
# <AxesSubplot:>

# %%
gold.rolling(window=4).mean().plot()
# Out:
# <AxesSubplot:>

# %%
gold.rolling(window=6).mean().plot()
# Out:
# <AxesSubplot:>

# %%
gold.rolling(window=8).mean().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Done!
